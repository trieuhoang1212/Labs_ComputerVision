# %% [markdown]
# ### **CANNY CÓ THỂ ĐƯỢC SỬ DỤNG ĐỂ PHÁT HIỆN CÁC CẠNH TRONG ẢNH MÀU KHÔNG? NẾU CÓ, THÌ NHƯ THẾ NÀO?**

# %% [markdown]
# *trả lời câu hỏi theo yêu cầu đề bài ở trong Lab3\assets\images\bai_tap.png*
