# %% [markdown]
# ## **TẠO MÃ BĂM:**

# %%
from hash_utils import wavelet_hash

# %%
image_path = "../1_data_preparation/dataset/similar/img1.jpg"

hash_code = wavelet_hash(image_path)

print("Độ dài hash:", len(hash_code))
print("20 bit đầu:", hash_code[:20])
