# %% [markdown]
# ## **XÂY DỰNG ỨNG DỤNG TÌM KIẾM HÌNH ẢNH DỰA TRÊN HÀM BĂM WAVELET:**
#
# #### **1. Wavelet là gì?**
# - **Wavelet** thì có thể hiểu nó giúp nhìn được tổng thể, soi được cá tin hiệu nhỏ trong ảnh. Fourier cũng giống với **Wavelet** nó có thể bắt được tần số nhưng không không tìm được vị trí hình ảnh. Còn ở **wavelet** thì vừa có thể bắt được tần số hình ảnh và biết được vị trí hình ảnh ở đâu nên rất hữu ích trong việc sửa chữa các hình ảnh mà _không bị vỡ hình_. Ngoài ra thì **wavelet** cũng được sử dụng trong _nén ảnh_, làm _âm thanh_ và _y sinh_.
#
# #### **2. Time và Frequecy Domains là gì ?**
# ##### **2.1 Mối quan hệ:**
# **Time** này như ở nói trên là nó biết được "vị trí" hình ảnh ở đâu nhưng không đoán được "tần số".
# Còn về **Frequecy** thì nó ngược lại là biết được "tần số" nhưng mù "vị trí".
#
# >Vậy: 1 thằng thì phân tích tín hiệu và 1 thằng thì phục hồi tín hiệu để bảo cho nhau.
#
# **Thực tế trong hình ảnh:**
# - **Tần số thấp** → Vùng màu mượt, ít chi tiết.
# - **Tần số cao** → Cạnh sắc nét, chi tiết nhỏ.
#
# #### 3. Wavelet trong hình ảnh:
# Nó gồm 4 thành phần chính:
#  ![image.png](attachment:image.png)
# _Nguồn: https://viblo.asia/p/wavelet-oKLnqBZNJQO - Wavelet_
#
# Và mỗi phần khi ca thiệp vào:
#  ![image-2.png](attachment:image-2.png)
#  _Nguồn: https://viblo.asia/p/wavelet-oKLnqBZNJQO - Wavelet_

# %% [markdown]
# ### **ÁP DỤNG THƯ VIỆN PYWAVELET:**

# %% [markdown]
# ở đây mình có một ví dụ đơn giản về pywavelet khi chạy trên python.
# - Đầu tiên là tạo hàm
# ``` python
# # tạo hàm
# import pywt
# # Áp dụng
# cA, cD = pywt.dwt([1, 2, 3, 4], 'db1')
# ```
# - Sau đó là ta có:
#
#     `cA` và `cD` lần lược là hệ số hiển thì thành phần tần số thấp và cao, vừa là hệ số sấp xỉ và hệ số chi tiết.
#
#     `[1, 2, 3, 4]`: Đây là tín hiệu đầu vào (dạng mảng 1D).
#
# Sau đây là đoạn code mẫu.
#
# _Nguồn: https://pywavelets.readthedocs.io/en/latest/_

# %%
import matplotlib.pyplot as plt
import numpy as np

import pywt
import pywt.data

# Load image
original = pywt.data.camera()

# Wavelet transform of image, and plot approximation and details
titles = ['Approximation', ' Horizontal detail',
          'Vertical detail', 'Diagonal detail']
coeffs2 = pywt.dwt2(original, 'bior1.3')
LL, (LH, HL, HH) = coeffs2
fig = plt.figure(figsize=(12, 3))
for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()
